# %% [markdown]
# # Prerequisite

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# Copyright (C) 2017 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
import os

# %%
PATH = '/content/drive/MyDrive/Trí tuệ nhân tạo/[CS106_Final project] EVRP/Source code/'

# %% [markdown]
# # Build c++

# %%
work_space = PATH + 'GA/'
os.chdir(work_space)

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Trí tuệ nhân tạo/[CS106_Final project] EVRP/Source code/GA

# %%
# %ls

# %%
# !g++ -Wall -std=c++14 *.cpp -o main

# %% [markdown]
# # Run

# %%
# !chmod a+x main
# !./main ../benchmark/E-n33-k4.evrp
# Out:
# Run: 3 with random seed 19520169
# End of run 3 with best solution quality 844.252 total evaluations: 982497

# %% [markdown]
# # Visualize

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Trí tuệ nhân tạo/[CS106_Final project] EVRP/Source code/GA

# %%
# %ls
# Out:
# file_1.txt  location.txt

# %%
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(11)
#!/usr/bin/python
f = open(work_space + 'Data/' + 'file_3.txt', 'r')
f_location = open(work_space + 'Data/' + 'location.txt', 'r')

string = f.read()
str = string.split()
num_of_node = int(str[0])

string2 = f_location.read()
str2 = string2.split()

X1 = []
X2 = []

for a in str2:
    X2.append(float(a))
loc = []
M = len(X2)
for i in range(M):
    if(i % 3 == 0):
        a = []
        a.append(int(X2[i]))
        a.append(X2[i + 1])
        a.append(X2[i + 2])
        loc.append(a)
        
for i in range(1, num_of_node * 2, 2):
    X1.append([int(str[i]), int(str[i + 1])])


def plot_map(X):
    for i in range(int(M / 3)):
        k = X[i][0]
        x1 = X[i][1]
        y1 = X[i][2]
        if k == 1:
            plt.plot(x1, y1, 'g^', markersize = 3, alpha = .8)
        if k == 2:
            plt.plot(x1, y1, 'bs', markersize = 6, alpha = .8)
    # plt.xlabel('EVRP', color = 'purple')
    # plt.axis('equal')
    # plt.plot(X[:, 0], X[:, 1])
    # plt.show()

def plot_tour(X2):
    for i in range(num_of_node - 1):
        x1, y1, x2, y2 = X2[i][0], X2[i][1], X2[i + 1][0], X2[i + 1][1]
        plt.plot([x1, x2], [y1, y2], color = 'tomato', linewidth = 1)
        # print(x1, y1, x2, y2)
    # plt.xlabel('EVRP', color = 'purple')
    # plt.xlabel('Generation', color = 'black')
    # plt.ylabel('Tour length', color = 'black')
    # plt.show()
    plt.plot(loc[0][1], loc[0][2], 'ro', markersize = 7, alpha = .8)
    # plt.savefig('n459k26_graph.pdf',bbox_inches='tight')
    # plt.axis('equal')
    # plt.plot(X[:, 0], X[:, 1])
    # plt.show()

plot_map(loc)
plot_tour(X1)
